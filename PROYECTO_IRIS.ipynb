# %% [markdown]
# <a href="https://colab.research.google.com/github/CGS002543/Python-proyect/blob/main/PROYECTO_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Proyecto Iris

# %%
#IMPORTANDO LIBRERIAS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0c056f91-a9d7-4343-8084-f2a3810721ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c056f91-a9d7-4343-8084-f2a3810721ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Generar un DataFrame con los datos del fichero
df=pd.read_csv('iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
#eliminando nan
df.dropna()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# Mostrar por pantalla las dimensiones del DataFrame, el número de datos que contiene, los nombres de sus columnas y filas, los tipos de datos de las columnas, las 10 primeras filas y las 10 últimas filas.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#maximo
df.max()
# Out:
# sepal.length          7.9
# sepal.width           4.4
# petal.length          6.9
# petal.width           2.5
# variety         Virginica
# dtype: object

# %%
#media variable 'sepal.width'
df['sepal.width'].mean()
# Out:
# np.float64(3.0573333333333337)

# %%
#media variable 'petal.width'
df['petal.width'].mean()
# Out:
# np.float64(1.1993333333333336)

# %%
#moda en varieble 'sepal.width'
df['sepal.width'].value_counts()
# Out:
# sepal.width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.3     6
# 3.5     6
# 3.8     6
# 2.6     5
# 3.6     4
# 2.3     4
# 3.7     3
# 2.2     3
# 2.4     3
# 3.9     2
# 4.4     1
# 4.2     1
# 4.1     1
# 4.0     1
# 2.0     1
# Name: count, dtype: int64

# %%
#varianza
df.var(numeric_only=True)
# Out:
# sepal.length    0.685694
# sepal.width     0.189979
# petal.length    3.116278
# petal.width     0.581006
# dtype: float64

# %%
#moda en varieble 'sepal.length	'
df['sepal.length'].value_counts()
# Out:
# sepal.length
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 6.4     7
# 5.5     7
# 5.8     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 6.2     4
# 4.4     3
# 7.2     3
# 5.9     3
# 6.8     3
# 4.7     2
# 6.6     2
# 4.3     1
# 7.0     1
# 5.3     1
# 4.5     1
# 7.1     1
# 7.3     1
# 7.6     1
# 7.4     1
# 7.9     1
# Name: count, dtype: int64

# %%
#max-min-media-df
df.describe(	)
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#CANTIDAD DE REGISTROS
print(df.shape)
# Out:
# (150, 5)

# %%
#grafico de pastel
serie=df.variety.value_counts()
serie.plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#histograma
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#importando libreria seaborn
from seaborn import lmplot

# %%
#grafico de dispersion
lmplot (x='sepal.length', y='sepal.width', data=df, fit_reg=True)

# %%
#grafico de dispersion 2
lmplot (x="sepal.length", y="petal.length", hue="variety", data=df)

# %%
#grafico de caja y bigote
plt.boxplot(df['sepal.width'],vert=False)
plt.show()

# %%
#Primer Cuartil
Q1 = df ['sepal.width'].quantile(0.25)
print('Primer Cuartil', Q1)
# Out:
# Primer Cuartil 2.8

# %%
#Tercer Cuartil
Q3 = df['sepal.width'].quantile(0.75)
print('Tercer Cuartil', Q3)
# Out:
# Tercer Cuartil 3.3

# %%
#Rango Intercuartil
IQR = Q3 - Q1
print('Rango Intercuartil', IQR)
# Out:
# Rango Intercuartil 0.5

# %%
#calculo del bigote inferior
BI_Calculado=(Q1-1.5*IQR)
print ("BI_Calculado \n", BI_Calculado)
# Out:
# BI_Calculado
#  2.05

# %%
#calculo del bigote superior
BS_Calculado=(Q3+1.5*IQR)
print ("BS_Calculado \n", BS_Calculado)
# Out:
# BS_Calculado
#  4.05

# %%
#verificacion ouliers segun rangos calculados
BI_Calculado=(Q1-1.5*IQR)
print ("BI_Calculado \n", BI_Calculado)
# Out:
# BI_Calculado
#  2.05

# %%
#valores sin outliers segun rangos entregados
ubicacion_sin_outliers=(df['sepal.width']>=BI_Calculado) & (df['sepal.width']<=BS_Calculado)
sin_outliers=df[ubicacion_sin_outliers]
print ("\n Ubicación sin  Outliers Vn", ubicacion_sin_outliers)
# Out:
#  Ubicación sin  Outliers Vn 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: sepal.width, Length: 150, dtype: bool

# %%
#grafico de caja y bigote con valores sin outiers
plt.boxplot(sin_outliers['sepal.width'],vert=False)
plt.show()
